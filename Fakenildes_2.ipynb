# %% [markdown]
# <a href="https://colab.research.google.com/github/SamiraHabib/Fake_News/blob/main/Fakenildes_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Vetorização do texto**

# %%
import pandas as pd
import numpy as np

# %%
import spacy
from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from unicodedata import normalize
import re
import nltk

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.
# True

# %%
data_df = pd.read_json('https://raw.githubusercontent.com/SamiraHabib/Fake_News/main/fakeNews%20_temp3.json')

# %% [markdown]
# ##**Criar coluna de texto corrido**

# %%
data_df['review_total'] = ""
for x in range(len(data_df)):
  data_df['review_total'][x] = " ".join([data_df['review_title'][x], data_df['review_resume'][x],
                                         data_df['review_conclusion'][x]])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ##**Spacy**

# %% [markdown]
# SAPCY en_core_web_trf: Large and acuratte english pipeline optimized for CPU about WEB written text (blogs, news, comments). English Vocabulary, syntax, entities and vectors
#
# Components: tok2vec, tagger, parser, senter, ner, attribute_ruler, lemmatizer.

# %%
# !pip install spacy
# !python -m spacy download en
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.5.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.4.1)
# Requirement already satisfied: en_core_web_sm==2.2.5 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz#egg=en_core_web_sm==2.2.5 in /usr/local/lib/python3.7/dist-packages (2.2.5)
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.4.1)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
#Amiga aqui eu to fazendo o de-para de nltk pra spacy,
#é a mesma função que eu contrui pro remove_stopword do nltk só que com as chamadas da biblioteca do spacy

# %% [markdown]
# **Tirando pontuação e transformando em minúsculo**

# %%
df_preprocess = pd.DataFrame()

# %% [markdown]
# **Tokenizando as palavras do texto**

# %%
### Adicionando pontuação as stopwords
stopwords = nltk.corpus.stopwords.words('english')
stopwords = list (set(stopwords))
STOPWORDS = stopwords + list (punctuation)

# %%
normalized_list = []

for item in data_df['review_total']:
  norm = normalize('NFKD', item).encode('ASCII', 'ignore').decode('ASCII')
  normalized_list.append(norm.lower().replace(',','').replace(':','').replace('?','').replace('"','').replace('\'s','').replace('\'','').replace('!',''))

df_preprocess['normalized'] = normalized_list

# %%
df_preprocess
# Out:
#                                              normalized
# 0     normandy summit results the eu plays on russia...
# 1     the us benefits from the attack on the saudi o...
# 2     the polish legions of pilsudski organized the ...
# 3     the west might use the eastern europeans as ca...
# 4     the resolution of the european parliament reli...
# ...                                                 ...
# 7361  us wants to divide syria the usa wants to divi...
# 7362  obama was close to succeeding where hitler fai...
# 7363  european parliament falsifies history about mo...
# 7364  european parliament falsifies history about mo...
# 7365  the us is helping terrorists in afghanistan a ...
#
# [7366 rows x 1 columns]

# %%
df_preprocess['regex'] = df_preprocess['normalized'].apply(lambda x: re.sub('[0-9]|,|\.|/|$|\(|\)|-|\+|:|•', '', str(x)))

# %%
df_preprocess
# Out:
#                                              normalized                                              regex
# 0     normandy summit results the eu plays on russia...  normandy summit results the eu plays on russia...
# 1     the us benefits from the attack on the saudi o...  the us benefits from the attack on the saudi o...
# 2     the polish legions of pilsudski organized the ...  the polish legions of pilsudski organized the ...
# 3     the west might use the eastern europeans as ca...  the west might use the eastern europeans as ca...
# 4     the resolution of the european parliament reli...  the resolution of the european parliament reli...
# ...                                                 ...                                                ...
# 7361  us wants to divide syria the usa wants to divi...  us wants to divide syria the usa wants to divi...
# 7362  obama was close to succeeding where hitler fai...  obama was close to succeeding where hitler fai...
# 7363  european parliament falsifies history about mo...  european parliament falsifies history about mo...
# 7364  european parliament falsifies history about mo...  european parliament falsifies history about mo...
# 7365  the us is helping terrorists in afghanistan a ...  the us is helping terrorists in afghanistan a ...
#
# [7366 rows x 2 columns]

# %%
tokenizer = English()

# %%
df_preprocess['tokenized'] = df_preprocess.apply(lambda x: tokenizer(x['regex']), axis=1)

# %%
df_preprocess['tokenized'][0]
# Out:
# normandy summit results the eu plays on russia side and betrayed kyiv no bright future for ukraine ukraine has put itself in a situation when external forces dictate how it should solve its internal problems kyiv expected that its western allies will put pressure on russia in the normandy four format however the allies realised that their confrontation with russia will cost them more emmanuel macron and angela merkel supported russias position and put even bigger pressure on ukraine than vladimir putin did eventually zelenskyy found himself in solitude because russia germany and france had nearly identical positions regarding the resolution of the civil conflict in ukraine ukrainian politicians wrongfully remain confident that the west will always unconditionally support any russophobic regime and that ukraine can just carry out its foreign policy and security under the wests authority to enjoy its protectionukraine could slam the door and declare that it no longer needs the normandy format however it is the last remaining material evidence of ukraines unity with the west and of its movement towards europe which kyiv can present to the ukrainian people if the truth is told to the ukrainians that europe represented by paris and berlin is already playing along with russia then ukrainian people will reasonably question for what were people sacrificed and state and society destroyed if in the end europe betrayed ukraine ukraine will never be in the eu and a bright future will never come this article misrepresents the actual german and french positions in the normandy summit and masks the clear violation of ukrainian sovereignty and territorial integrity by acts of aggression by the russian armed forces since february  as ukraine internal problems and civil conflict it also challenges ukrainian statehood and sovereignty and promotes recurring prokremlin propagandistic narrative about ukraine inevitable bleak future its disintegration and imminent collapse
# the claim that germany and france play along with russia is groundless according to the common agreed conclusions of the normandy summit of  december  the minsk agreements minsk protocol of  september  minsk memorandum of  september  and the minsk package of measures of  february  continue to be the basis of the work of the normandy format whose member states are committed to their full implementation the minsk package of measures of  february  among other things without mentioning russian personnel and hardware by name calls for the withdrawal of all foreign armed formations military equipment as well as mercenaries from the territory of ukraine under monitoring of the osce para
# read our articles about antiukrainian propaganda ukraine under information fire and five years of falsehoods was it worth the while for the kremlin as well as earlier disinformation cases claiming that ukraine invariably faces civil war and complete disintegration that ukraine will be disintegrated by  that the normandy summit aimed at solving ukraines internal problems and that germany fabricated a new skripal case ahead of normandy summit

# %% [markdown]
# **Criando lista de stopwords e removendo-as do texto**

# %%
spacy_stopwords = list(set(spacy.lang.en.stop_words.STOP_WORDS))

# %%
words_lists = []

for item in df_preprocess['tokenized']:
  word_temp = []
  for word in item:
    if word.text not in spacy_stopwords:
      word_temp.append(word)
  words_lists.append(word_temp)

df_preprocess['stopwords'] = words_lists

# %%
df_preprocess.head()
# Out:
#                                           normalized  ...                                          stopwords
# 0  normandy summit results the eu plays on russia...  ...  [normandy, summit, results, eu, plays, russia,...
# 1  the us benefits from the attack on the saudi o...  ...  [benefits, attack, saudi, oil, facility, regar...
# 2  the polish legions of pilsudski organized the ...  ...  [polish, legions, pilsudski, organized, volyn,...
# 3  the west might use the eastern europeans as ca...  ...  [west, use, eastern, europeans, cannon, fodder...
# 4  the resolution of the european parliament reli...  ...  [resolution, european, parliament, relieves, g...
#
# [5 rows x 4 columns]

# %% [markdown]
# ##Nuvem de palavras com imagem png
#
# Usando o dataframe que contém as palavras normalizadas

# %%
import pandas as pd
import numpy as np

#for plotting images & adjusting colors
import matplotlib.pyplot as plt
import matplotlib as mpl
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
summary = df_preprocess['normalized']

# %%
# concatenar as palavras
all_summary = " ".join(s for s in summary)

# lista de stopword
stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os"])

# gerar uma wordcloud
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="black",
                      width=1600, height=800).generate(all_summary)

# mostrar a imagem final
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud);
wordcloud.to_file("airbnb_summary_wordcloud.png")

# %%
# endereço LOCAL da SUA imagem
rio_mask = np.array(Image.open("/content/6e197387ee473cf4751e6b285f68ad09.png"))
   
# gerar uma wordcloud
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="white",
                      width=1000, height=1000, max_words=2000,
                      mask=rio_mask, max_font_size=200,
                      min_font_size=1).generate(all_summary)
 
# mostrar a imagem final
fig, ax = plt.subplots(figsize=(14,14))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud)
wordcloud.to_file("airbnb_summary_wordcloud.png")

# %%
#(site: https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/)

# %%
#words_compr = []
#for idx, item in enumerate(df_preprocess['stopwords']):
 # words_compr.append(nlp(str(item)))

# %% [markdown]
# ###Lista de entidade em cada texto

# %%
#words_compr[4].ents

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
#fit modelo
#transform text

# %%
text = df_preprocess['stopwords'].to_string(index=False).replace('\n','').replace(',','')

# %%
text
# Out:
# ' [normandy summit results eu plays russia... [benefits attack saudi oil facility regar... [polish legions pilsudski organized volyn... [west use eastern europeans cannon fodder... [resolution european parliament relieves g... [tentacles george soros entangle politics... [protests hong kong usfunded growing back... [antisemitism ukraine rise particular conc... [threats kaliningrad stands chance ministr... [western propaganda masters control mass ... [liberalglobalism totalitarian ideology dom... [liberalglobalism totalitarian ideology dom... [sanctions russia unproductive eu sanction... [support nato ukraine falling number peop... [wadas decision russia politically motivat... [foreign aid hinders return syrian refuge... [western media campaign supports preparati... [goal crimea takeover save donbaslike civ... [goal crimea takeover save donbaslike civ... [molotovribbentrop pact pave way outbreak... [red army liberated estonia nazi army wa... [ukrainians paid snitching local corrupt ... [estonia tool hands eu estonia tool hand... [red army nt want bomb citizens tallinn... [terrorists white helmets prepare false f... [chemical attack khan shaykhun staged whi... [purpose removing monument marshall konev... [wants capture kaliningrad exchange crimea... [european parliament joined forces fascism... [estonian authorities pay tribute hitlers... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [eu army sent suppress new brexits eu a... [europe creates obstacles cooperation russ... [lithuania direct beneficiary molotovribben... [fsb revealed involvement transportation i... [ussr ally nazi germany ussr ally nazi ... [ussr ally nazi germany ussr ally nazi ... [western politicians accuse sputnik rt el... [drone attack saudi oil facilities false... [western media distort election results p... [western media distort election results p... [moldova refuses support ukrainian plan s... [moldova refuses support ukrainian plan s... [russia stop americanisation ukraine way ... [eu wants create army defend european un... [mh russia gave evidence joint investigat... [european parliament carries political hat... [ep allows destruction monuments fighters... [ep allows destruction monuments fighters... [west shown cards russia fall   main bl... [west shown cards russia fall   main bl... [cherry sanctions eu fruit exports lose ... [imperialistic poland feeds animosities uk... [evidence russian meddling french election... [brexit greatest victory eu history uks ... [washington playing religion card societie... [stronger alliance poland wants dictate r... [hong kong protests west revenge china w... [nato preparing command centre germany wa... [ukraine preparing disruption gas transit... [  september   ussr began liberating pol... [eu accept ukraine allowing products mark... [zelenskyy stands sanctions initiative rig... [west chose russia main opponent collapse... [europe transit gas ukraine form subsidy... [americans interested disrupting gas trans... [ukrainian gas transmission system environ... [ukraine willing sign new contract gas t... [poland blame attacked stalin     septem... [g countries insignificant fully sovereign... [poland sympathises willing fight russia ... [poland sympathises willing fight russia ... [task european defence agency maintain na... [isolated ussr alternative sign molotovrib... [konev monument small clique junior offic... [removal monument marshall konev violation... [local gauleiter wants remove statue mars... [european political elites forced stupidly... [amnesty international red cross missionar... [echr makes decisions based antirussian l... [lovely face liberalism open cannibalism ... [west organised maidan coup ukraine antir... [west targeted russia sanct ...

# %%
from spacy.lang.en import English
 
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = English()
 
#for itens in df_preprocess['stopwords'].iteritems():
 #   text = itens
 
#  "nlp" Object is used to create documents with linguistic annotations.
my_doc = nlp(text)
 
token_list = []
for token in my_doc:
  token_list.append(token.text)
print(token_list)
# Out:
# [' ', '[', 'normandy', 'summit', 'results', 'eu', 'plays', 'russia', '...', '[', 'benefits', 'attack', 'saudi', 'oil', 'facility', 'regar', '...', '[', 'polish', 'legions', 'pilsudski', 'organized', 'volyn', '...', '[', 'west', 'use', 'eastern', 'europeans', 'cannon', 'fodder', '...', '[', 'resolution', 'european', 'parliament', 'relieves', 'g', '...', '[', 'tentacles', 'george', 'soros', 'entangle', 'politics', '...', '[', 'protests', 'hong', 'kong', 'usfunded', 'growing', 'back', '...', '[', 'antisemitism', 'ukraine', 'rise', 'particular', 'conc', '...', '[', 'threats', 'kaliningrad', 'stands', 'chance', 'ministr', '...', '[', 'western', 'propaganda', 'masters', 'control', 'mass', '...', '[', 'liberalglobalism', 'totalitarian', 'ideology', 'dom', '...', '[', 'liberalglobalism', 'totalitarian', 'ideology', 'dom', '...', '[', 'sanctions', 'russia', 'unproductive', 'eu', 'sanction', '...', '[', 'support', 'nato', 'ukraine', 'falling', 'number', 'peop', '...', '[', 'wadas', 'decision', 'russia', 'politically', 'motivat', '...', '[', 'foreign', 'aid', 'hinders', 'return', 'syrian', 'refuge', '...', '[', 'western', 'media', 'campaign', 'supports', 'preparati', '...', '[', 'goal', 'crimea', 'takeover', 'save', 'donbaslike', 'civ', '...', '[', 'goal', 'crimea', 'takeover', 'save', 'donbaslike', 'civ', '...', '[', 'molotovribbentrop', 'pact', 'pave', 'way', 'outbreak', '...', '[', 'red', 'army', 'liberated', 'estonia', 'nazi', 'army', 'wa', '...', '[', 'ukrainians', 'paid', 'snitching', 'local', 'corrupt', '...', '[', 'estonia', 'tool', 'hands', 'eu', 'estonia', 'tool', 'hand', '...', '[', 'red', 'army', 'nt', 'want', 'bomb', 'citizens', 'tallinn', '...', '[', 'terrorists', 'white', 'helmets', 'prepare', 'false', 'f', '...', '[', 'chemical', 'attack', 'khan', 'shaykhun', 'staged', 'whi', '...', '[', 'purpose', 'removing', 'monument', 'marshall', 'konev', '...', '[', 'wants', 'capture', 'kaliningrad', 'exchange', 'crimea', '...', '[', 'european', 'parliament', 'joined', 'forces', 'fascism', '...', '[', 'estonian', 'authorities', 'pay', 'tribute', 'hitlers', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'russophobia', 'driven', 'internal', 'political', 'pro', '...', '[', 'eu', 'army', 'sent', 'suppress', 'new', 'brexits', 'eu', 'a', '...', '[', 'europe', 'creates', 'obstacles', 'cooperation', 'russ', '...', '[', 'lithuania', 'direct', 'beneficiary', 'molotovribben', '...', '[', 'fsb', 'revealed', 'involvement', 'transportation', 'i', '...', '[', 'ussr', 'ally', 'nazi', 'germany', 'ussr', 'ally', 'nazi', '...', '[', 'ussr', 'ally', 'nazi', 'germany', 'ussr', 'ally', 'nazi', '...', '[', 'western', 'politicians', 'accuse', 'sputnik', 'rt', 'el', '...', '[', 'drone', 'attack', 'saudi', 'oil', 'facilities', 'false', '...', '[', 'western', 'media', 'distort', 'election', 'results', 'p', '...', '[', 'western', 'media', 'distort', 'election', 'results', 'p', '...', '[', 'moldova', 'refuses', 'support', 'ukrainian', 'plan', 's', '...', '[', 'moldova', 'refuses', 'support', 'ukrainian', 'plan', 's', '...', '[', 'russia', 'stop', 'americanisation', 'ukraine', 'way', '...', '[', 'eu', 'wants', 'create', 'army', 'defend', 'european', 'un', '...', '[', 'mh', 'russia', 'gave', 'evidence', 'joint', 'investigat', '...', '[', 'european', 'parliament', 'carries', 'political', 'hat', '...', '[', 'ep', 'allows', 'destruction', 'monuments', 'fighters', '...', '[', 'ep', 'allows', 'destruction', 'monuments', 'fighters', '...', '[', 'west', 'shown', 'cards', 'russia', 'fall', '  ', 'main', 'bl', '...', '[', 'west', 'shown', 'cards', 'russia', 'fall', '  ', 'main', 'bl', '...', '[', 'che ...

# %% [markdown]
# ###Sentença

# %%
nlp = English()
 
# Create the pipeline 'sentencizer' component
sbd = nlp.create_pipe('sentencizer')
 
# Add the component to the pipeline
nlp.add_pipe(sbd)
 
#  "nlp" Object is used to create documents with linguistic annotations.
doc = nlp(text)
 
# create list of sentence tokens
sents_list = []
for sent in doc.sents:
    sents_list.append(sent.text)
print(sents_list)
# Out:
# [' [normandy summit results eu plays russia... [benefits attack saudi oil facility regar... [polish legions pilsudski organized volyn... [west use eastern europeans cannon fodder... [resolution european parliament relieves g... [tentacles george soros entangle politics... [protests hong kong usfunded growing back... [antisemitism ukraine rise particular conc... [threats kaliningrad stands chance ministr... [western propaganda masters control mass ... [liberalglobalism totalitarian ideology dom... [liberalglobalism totalitarian ideology dom... [sanctions russia unproductive eu sanction... [support nato ukraine falling number peop... [wadas decision russia politically motivat... [foreign aid hinders return syrian refuge... [western media campaign supports preparati... [goal crimea takeover save donbaslike civ... [goal crimea takeover save donbaslike civ... [molotovribbentrop pact pave way outbreak... [red army liberated estonia nazi army wa... [ukrainians paid snitching local corrupt ... [estonia tool hands eu estonia tool hand... [red army nt want bomb citizens tallinn... [terrorists white helmets prepare false f... [chemical attack khan shaykhun staged whi... [purpose removing monument marshall konev... [wants capture kaliningrad exchange crimea... [european parliament joined forces fascism... [estonian authorities pay tribute hitlers... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [russophobia driven internal political pro... [eu army sent suppress new brexits eu a... [europe creates obstacles cooperation russ... [lithuania direct beneficiary molotovribben... [fsb revealed involvement transportation i... [ussr ally nazi germany ussr ally nazi ... [ussr ally nazi germany ussr ally nazi ... [western politicians accuse sputnik rt el... [drone attack saudi oil facilities false... [western media distort election results p... [western media distort election results p... [moldova refuses support ukrainian plan s... [moldova refuses support ukrainian plan s... [russia stop americanisation ukraine way ... [eu wants create army defend european un... [mh russia gave evidence joint investigat... [european parliament carries political hat... [ep allows destruction monuments fighters... [ep allows destruction monuments fighters... [west shown cards russia fall   main bl... [west shown cards russia fall   main bl... [cherry sanctions eu fruit exports lose ... [imperialistic poland feeds animosities uk... [evidence russian meddling french election... [brexit greatest victory eu history uks ... [washington playing religion card societie... [stronger alliance poland wants dictate r... [hong kong protests west revenge china w... [nato preparing command centre germany wa... [ukraine preparing disruption gas transit... [  september   ussr began liberating pol... [eu accept ukraine allowing products mark... [zelenskyy stands sanctions initiative rig... [west chose russia main opponent collapse... [europe transit gas ukraine form subsidy... [americans interested disrupting gas trans... [ukrainian gas transmission system environ... [ukraine willing sign new contract gas t... [poland blame attacked stalin     septem... [g countries insignificant fully sovereign... [poland sympathises willing fight russia ... [poland sympathises willing fight russia ... [task european defence agency maintain na... [isolated ussr alternative sign molotovrib... [konev monument small clique junior offic... [removal monument marshall konev violation... [local gauleiter wants remove statue mars... [european political elites forced stupidly... [amnesty international red cross missionar... [echr makes decisions based antirussian l... [lovely face liberalism open cannibalism ... [west organised maidan coup ukraine antir... [west targeted russia sanc ...

# %% [markdown]
# ###STOPWORDS

# %%
import spacy
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
 
#Printing the total number of stop words:
print('Number of stop words: %d' % len(spacy_stopwords))
 
#Printing first ten stop words:
print('First ten stop words: %s' % list(spacy_stopwords)[:20])
# Out:
# Number of stop words: 326
# First ten stop words: ['will', 'none', 'the', 'wherever', 'else', 'both', 'my', 'mine', 'enough', 'beyond', 'really', 'us', 'noone', 'top', '‘ve', 'every', 'themselves', 'others', 'twenty', "'s"]

# %% [markdown]
# ###SENTENÇA FILTRADA

# %%
from spacy.lang.en.stop_words import STOP_WORDS
 
#Implementation of stop words:
filtered_sent=[]
 
#  "nlp" Object is used to create documents with linguistic annotations.
doc = nlp(text)
 
# filtering stop words
for word in doc:
    if word.is_stop==False:
        filtered_sent.append(word)
print("Filtered Sentence:",filtered_sent)
# Out:
# Filtered Sentence: [ , [, normandy, summit, results, eu, plays, russia, ..., [, benefits, attack, saudi, oil, facility, regar, ..., [, polish, legions, pilsudski, organized, volyn, ..., [, west, use, eastern, europeans, cannon, fodder, ..., [, resolution, european, parliament, relieves, g, ..., [, tentacles, george, soros, entangle, politics, ..., [, protests, hong, kong, usfunded, growing, ..., [, antisemitism, ukraine, rise, particular, conc, ..., [, threats, kaliningrad, stands, chance, ministr, ..., [, western, propaganda, masters, control, mass, ..., [, liberalglobalism, totalitarian, ideology, dom, ..., [, liberalglobalism, totalitarian, ideology, dom, ..., [, sanctions, russia, unproductive, eu, sanction, ..., [, support, nato, ukraine, falling, number, peop, ..., [, wadas, decision, russia, politically, motivat, ..., [, foreign, aid, hinders, return, syrian, refuge, ..., [, western, media, campaign, supports, preparati, ..., [, goal, crimea, takeover, save, donbaslike, civ, ..., [, goal, crimea, takeover, save, donbaslike, civ, ..., [, molotovribbentrop, pact, pave, way, outbreak, ..., [, red, army, liberated, estonia, nazi, army, wa, ..., [, ukrainians, paid, snitching, local, corrupt, ..., [, estonia, tool, hands, eu, estonia, tool, hand, ..., [, red, army, nt, want, bomb, citizens, tallinn, ..., [, terrorists, white, helmets, prepare, false, f, ..., [, chemical, attack, khan, shaykhun, staged, whi, ..., [, purpose, removing, monument, marshall, konev, ..., [, wants, capture, kaliningrad, exchange, crimea, ..., [, european, parliament, joined, forces, fascism, ..., [, estonian, authorities, pay, tribute, hitlers, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, russophobia, driven, internal, political, pro, ..., [, eu, army, sent, suppress, new, brexits, eu, ..., [, europe, creates, obstacles, cooperation, russ, ..., [, lithuania, direct, beneficiary, molotovribben, ..., [, fsb, revealed, involvement, transportation, ..., [, ussr, ally, nazi, germany, ussr, ally, nazi, ..., [, ussr, ally, nazi, germany, ussr, ally, nazi, ..., [, western, politicians, accuse, sputnik, rt, el, ..., [, drone, attack, saudi, oil, facilities, false, ..., [, western, media, distort, election, results, p, ..., [, western, media, distort, election, results, p, ..., [, moldova, refuses, support, ukrainian, plan, s, ..., [, moldova, refuses, support, ukrainian, plan, s, ..., [, russia, stop, americanisation, ukraine, way, ..., [, eu, wants, create, army, defend, european, un, ..., [, mh, russia, gave, evidence, joint, investigat, ..., [, european, parliament, carries, political, hat, ..., [, ep, allows, destruction, monuments, fighters, ..., [, ep, allows, destruction, monuments, fighters, ..., [, west, shown, cards, russia, fall,   , main, bl, ..., [, west, shown, cards, russia, fall,   , main, bl, ..., [, cherry, sanctions, eu, fruit, exports, lose, ..., [, imperialistic, poland, feeds, animosities, uk, ..., [, evidence, russian, meddling, french, election, ..., [, brexit, greatest, victory, eu, history, uks, ..., [, washington, playing, religion, card, societie, ..., [, stronger, alliance, poland, wants, dictate, r, ..., [, hong, kong, protests, west, revenge, china, w, ..., [, nato, preparing, command, centre, germany, wa, ..., [, ukraine, preparing, disruption, gas, transit, ..., [,  , september,   , ussr, began, liberating, pol, ..., [, eu, accept, ukraine, allowing, products, mark, ..., [, zelenskyy, stands, sanctions, initiative, rig, ..., [, west, chose, russia, main, opponent, collapse, ..., [, europe, transit, gas, ukraine, form, subsidy, ..., [, americans, interested, disrupting, gas, trans, ..., [, ukrainian, gas, transmission, system, environ, .. ...

# %% [markdown]
# **Classificação gramatical de cada palavra**

# %%
doc = nlp(text)
for token in doc:
  print(token.text, "|", token.lemma_, "|", token.is_alpha, "|", token.is_punct, "|", token.is_digit, "|", token.like_num)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# eu | eu | True | False | False | False
# magnitsky | magnitsky | True | False | False | False
# sanctions | sanctions | True | False | False | False
# way | way | True | False | False | False
# distract | distract | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# eu | eu | True | False | False | False
# magnitsky | magnitsky | True | False | False | False
# sanctions | sanctions | True | False | False | False
# way | way | True | False | False | False
# distract | distract | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# colour | colour | True | False | False | False
# revolutions | revolutions | True | False | False | False
# west | west | True | False | False | False
# interfere | interfere | True | False | False | False
# affairs | affairs | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# euromaidan | euromaidan | True | False | False | False
# directed | directed | True | False | False | False
# western | western | True | False | False | False
# puppeteers | puppeteers | True | False | False | False
# eu | eu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
#   |   | False | False | False | False
# nato | nato | True | False | False | False
# leadership | leadership | True | False | False | False
# disrupted | disrupted | True | False | False | False
# libya | libya | True | False | False | False
#    |    | False | False | False | False
# nat | nat | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
#   |   | False | False | False | False
# nato | nato | True | False | False | False
# leadership | leadership | True | False | False | False
# disrupted | disrupted | True | False | False | False
# libya | libya | True | False | False | False
#    |    | False | False | False | False
# nat | nat | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
#   |   | False | False | False | False
# nato | nato | True | False | False | False
# leadership | leadership | True | False | False | False
# disrupted | disrupted | True | False | False | False
# libya | libya | True | False | False | False
#    |    | False | False | False | False
# nat | nat | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# cocacola | cocacola | True | False | False | False
# recognized | recognized | True | False | False | False
# crimea | crimea | True | False | False | False
# russian | russian | True | False | False | False
# territ | territ | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# battalions | battalions | True | False | False | False
# soldiers | soldiers | True | False | False | False
# turkey | turkey | True | False | False | False
# countries | countries | True | False | False | False
# batt | batt | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# edward | edward | True | False | False | False
# snowden | snowden | True | False | False | False
# says | says | True | False | False | False
# osama | osama | True | False | False | False
# bin | bin | True | False | False | False
# laden | laden | True | False | False | False
# ali | ali | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# edward | edward | True | False | False | False
# snowden | snowden | True | False | False | False
# says | says | True | False | False | False
# osama | osama | True | False | False | False
# bin | bin | True | False | False | False
# laden | laden | True | False | False | False
# ali | ali | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nato | nato | True | False | False | False
# escalates | escalates | True | False | False | False
# situation | situation | True | False | False | False
# europe | europe | True | False | False | False
# military | military | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russian | russian | True | False | False | False
# president | president | True | False | False | False
# peace | peace | True | False | False | False
# europeans | europeans | True | False | False | False
# usa | usa | True | False | False | False
# de | de | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russian | russian | True | False | False | False
# president | president | True | False | False | False
# peace | peace | True | False | False | False
# europeans | europeans | True | False | False | False
# usa | usa | True | False | False | False
# de | de | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russian | russian | True | False | False | False
# president | president | True | False | False | False
# peace | peace | True | False | False | False
# europeans | europeans | True | False | False | False
# usa | usa | True | False | False | False
# de | de | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russian | russian | True | False | False | False
# president | president | True | False | False | False
# peace | peace | True | False | False | False
# europeans | europeans | True | False | False | False
# usa | usa | True | False | False | False
# de | de | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russian | russian | True | False | False | False
# president | president | True | False | False | False
# peace | peace | True | False | False | False
# europeans | europeans | True | False | False | False
# usa | usa | True | False | False | False
# de | de | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# diaspora | diaspora | True | False | False | False
# condemned | condemned | True | False | False | False
# sanctions | sanctions | True | False | False | False
# po | po | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# diaspora | diaspora | True | False | False | False
# condemned | condemned | True | False | False | False
# sanctions | sanctions | True | False | False | False
# po | po | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# diaspora | diaspora | True | False | False | False
# condemned | condemned | True | False | False | False
# sanctions | sanctions | True | False | False | False
# po | po | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# diaspora | diaspora | True | False | False | False
# condemned | condemned | True | False | False | False
# sanctions | sanctions | True | False | False | False
# po | po | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukraine | ukraine | True | False | False | False
# cut | cut | True | False | False | False
# lnr | lnr | True | False | False | False
# water | water | True | False | False | False
# supply | supply | True | False | False | False
# ukraine | ukraine | True | False | False | False
# cu | cu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# deutsche | deutsche | True | False | False | False
# welle | welle | True | False | False | False
# angela | angela | True | False | False | False
# merkel | merkel | True | False | False | False
# insulted | insulted | True | False | False | False
# pr | pr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# current | current | True | False | False | False
# bulgarian | bulgarian | True | False | False | False
# prime | prime | True | False | False | False
# minister | minister | True | False | False | False
# boiko | boiko | True | False | False | False
# b | b | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# islam | islam | True | False | False | False
# product | product | True | False | False | False
# instrument | instrument | True | False | False | False
# hidden | hidden | True | False | False | False
# islam | islam | True | False | False | False
# pr | pr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# islam | islam | True | False | False | False
# product | product | True | False | False | False
# instrument | instrument | True | False | False | False
# hidden | hidden | True | False | False | False
# islam | islam | True | False | False | False
# pr | pr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# happening | happening | True | False | False | False
# syria | syria | True | False | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# s | s | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# happening | happening | True | False | False | False
# syria | syria | True | False | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# s | s | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# leaders | leaders | True | False | False | False
# trying | trying | True | False | False | False
# eradicate | eradicate | True | False | False | False
# christianity | christianity | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# czech | czech | True | False | False | False
# mainstream | mainstream | True | False | False | False
# media | media | True | False | False | False
# inform | inform | True | False | False | False
# new | new | True | False | False | False
# year | year | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# french | french | True | False | False | False
# people | people | True | False | False | False
# want | want | True | False | False | False
# putin | putin | True | False | False | False
# president | president | True | False | False | False
# frenc | frenc | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# turkish | turkish | True | False | False | False
# mercenaries | mercenaries | True | False | False | False
# going | going | True | False | False | False
# fight | fight | True | False | False | False
# donbass | donbass | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# crimea | crimea | True | False | False | False
# returned | returned | True | False | False | False
# russia | russia | True | False | False | False
# popular | popular | True | False | False | False
# referendum | referendum | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# children | children | True | False | False | False
# european | european | True | False | False | False
# brothels | brothels | True | False | False | False
# exot | exot | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# children | children | True | False | False | False
# european | european | True | False | False | False
# brothels | brothels | True | False | False | False
# exot | exot | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# happening | happening | True | False | False | False
# syria | syria | True | False | False | False
# west | west | True | False | False | False
# blame | blame | True | False | False | False
# s | s | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# joe | joe | True | False | False | False
# biden | biden | True | False | False | False
# gave | gave | True | False | False | False
# ukrainians | ukrainians | True | False | False | False
# goahead | goahead | True | False | False | False
# start | start | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# secretary | secretary | True | False | False | False
# russian | russian | True | False | False | False
# security | security | True | False | False | False
# council | council | True | False | False | False
# nikola | nikola | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# bailin | bailin | True | False | False | False
# system | system | True | False | False | False
# came | came | True | False | False | False
# effect | effect | True | False | False | False
# european | european | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# bailin | bailin | True | False | False | False
# system | system | True | False | False | False
# came | came | True | False | False | False
# effect | effect | True | False | False | False
# european | european | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# bailin | bailin | True | False | False | False
# system | system | True | False | False | False
# came | came | True | False | False | False
# effect | effect | True | False | False | False
# european | european | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# battalions | battalions | True | False | False | False
# soldiers | soldiers | True | False | False | False
# turkey | turkey | True | False | False | False
# countries | countries | True | False | False | False
# batt | batt | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# bbc | bbc | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# president | president | True | False | False | False
# petro | petro | True | False | False | False
# poroshenko | poroshenko | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldiers | soldiers | True | False | False | False
# raped | raped | True | False | False | False
# female | female | True | False | False | False
# polish | polish | True | False | False | False
# m | m | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldiers | soldiers | True | False | False | False
# raped | raped | True | False | False | False
# female | female | True | False | False | False
# polish | polish | True | False | False | False
# m | m | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# members | members | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# orthodox | orthodox | True | False | False | False
# church | church | True | False | False | False
# serve | serve | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# europe | europe | True | False | False | False
# realised | realised | True | False | False | False
# antirussian | antirussian | True | False | False | False
# sanctions | sanctions | True | False | False | False
# mea | mea | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# battalions | battalions | True | False | False | False
# soldiers | soldiers | True | False | False | False
# turkey | turkey | True | False | False | False
# countries | countries | True | False | False | False
# batt | batt | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# saboteurs | saboteurs | True | False | False | False
# trying | trying | True | False | False | False
# kill | kill | True | False | False | False
# russian | russian | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# official | official | True | False | False | False
# history | history | True | False | False | False
# lie | lie | True | False | False | False
# like | like | True | False | False | False
# official | official | True | False | False | False
# histo | histo | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# official | official | True | False | False | False
# history | history | True | False | False | False
# lie | lie | True | False | False | False
# like | like | True | False | False | False
# official | official | True | False | False | False
# histo | histo | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# refugees | refugees | True | False | False | False
# pay | pay | True | False | False | False
# lot | lot | True | False | False | False
# money | money | True | False | False | False
# smugglers | smugglers | True | False | False | False
# refugee | refugee | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# refugees | refugees | True | False | False | False
# pay | pay | True | False | False | False
# lot | lot | True | False | False | False
# money | money | True | False | False | False
# smugglers | smugglers | True | False | False | False
# refugee | refugee | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# refugees | refugees | True | False | False | False
# pay | pay | True | False | False | False
# lot | lot | True | False | False | False
# money | money | True | False | False | False
# smugglers | smugglers | True | False | False | False
# refugee | refugee | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# osce | osce | True | False | False | False
# observers | observers | True | False | False | False
# shelling | shelling | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# gunmen | gunmen | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# osce | osce | True | False | False | False
# observers | observers | True | False | False | False
# shelling | shelling | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# gunmen | gunmen | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# banderites | banderites | True | False | False | False
# cooking | cooking | True | False | False | False
# humans | humans | True | False | False | False
# banderites | banderites | True | False | False | False
# cook | cook | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# trend | trend | True | False | False | False
# time | time | True | False | False | False
# coup | coup | True | False | False | False
# new | new | True | False | False | False
# kyiv | kyiv | True | False | False | False
# authorities | authorities | True | False | False | False
# tr | tr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# daily | daily | True | False | False | False
# telegraph | telegraph | True | False | False | False
# published | published | True | False | False | False
# article | article | True | False | False | False
# dutch | dutch | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# delay | delay | True | False | False | False
# antiisis | antiisis | True | False | False | False
# operation | operation | True | False | False | False
# iraq | iraq | True | False | False | False
# evacuating | evacuating | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# delay | delay | True | False | False | False
# antiisis | antiisis | True | False | False | False
# operation | operation | True | False | False | False
# iraq | iraq | True | False | False | False
# evacuating | evacuating | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greta | greta | True | False | False | False
# thunberg | thunberg | True | False | False | False
# artificial | artificial | True | False | False | False
# project | project | True | False | False | False
# rackete | rackete | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# residents | residents | True | False | False | False
# villages | villages | True | False | False | False
# kiev | kiev | True | False | False | False
# control | control | True | False | False | False
# donbass | donbass | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# yearold | yearold | True | False | False | False
# russian | russian | True | False | False | False
# opposition | opposition | True | False | False | False
# activist | activist | True | False | False | False
# vlad | vlad | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# yearold | yearold | True | False | False | False
# russian | russian | True | False | False | False
# opposition | opposition | True | False | False | False
# activist | activist | True | False | False | False
# vlad | vlad | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# political | political | True | False | False | False
# scientist | scientist | True | False | False | False
# main | main | True | False | False | False
# enemy | enemy | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# political | political | True | False | False | False
# scientist | scientist | True | False | False | False
# main | main | True | False | False | False
# enemy | enemy | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# political | political | True | False | False | False
# scientist | scientist | True | False | False | False
# main | main | True | False | False | False
# enemy | enemy | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# state | state | True | False | False | False
# ukraine | ukraine | True | False | False | False
# destroyed | destroyed | True | False | False | False
# weeks | weeks | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# state | state | True | False | False | False
# ukraine | ukraine | True | False | False | False
# destroyed | destroyed | True | False | False | False
# weeks | weeks | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# state | state | True | False | False | False
# ukraine | ukraine | True | False | False | False
# destroyed | destroyed | True | False | False | False
# weeks | weeks | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# algorithms | algorithms | True | False | False | False
# changing | changing | True | False | False | False
# human | human | True | False | False | False
# nat | nat | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# ambassador | ambassador | True | False | False | False
# ukraine | ukraine | True | False | False | False
# un | un | True | False | False | False
# said | said | True | False | False | False
# w | w | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# su | su | True | False | False | False
# downing | downing | True | False | False | False
# turkey | turkey | True | False | False | False
# nato | nato | True | False | False | False
# behaved | behaved | True | False | False | False
# su | su | True | False | False | False
# downi | downi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# city | city | True | False | False | False
# kherson | kherson | True | False | False | False
# follow | follow | True | False | False | False
# donbass | donbass | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# city | city | True | False | False | False
# kherson | kherson | True | False | False | False
# follow | follow | True | False | False | False
# donbass | donbass | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# trend | trend | True | False | False | False
# time | time | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# army | army | True | False | False | False
# joined | joined | True | False | False | False
# mercena | mercena | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# daily | daily | True | False | False | False
# telegraph | telegraph | True | False | False | False
# published | published | True | False | False | False
# article | article | True | False | False | False
# dutch | dutch | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# germany | germany | True | False | False | False
# pulls | pulls | True | False | False | False
# patriot | patriot | True | False | False | False
# aerial | aerial | True | False | False | False
# defence | defence | True | False | False | False
# sys | sys | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# germans | germans | True | False | False | False
# worried | worried | True | False | False | False
# trial | trial | True | False | False | False
# ukraine | ukraine | True | False | False | False
# russia | russia | True | False | False | False
# ger | ger | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# christian | christian | True | False | False | False
# faith | faith | True | False | False | False
# persecuted | persecuted | True | False | False | False
# eu | eu | True | False | False | False
#    |    | False | False | False | False
# claims | claims | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# europe | europe | True | False | False | False
# finds | finds | True | False | False | False
# edge | edge | True | False | False | False
# abyss | abyss | True | False | False | False
# europe | europe | True | False | False | False
# finds | finds | True | False | False | False
# ed | ed | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# americans | americans | True | False | False | False
# built | built | True | False | False | False
# military | military | True | False | False | False
# base | base | True | False | False | False
# macedonia | macedonia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# russia | russia | True | False | False | False
# ukraine | ukraine | True | False | False | False
# weeks | weeks | True | False | False | False
# trend | trend | True | False | False | False
# r | r | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# majority | majority | True | False | False | False
# cypriots | cypriots | True | False | False | False
# wants | wants | True | False | False | False
# provide | provide | True | False | False | False
# russians | russians | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# group | group | True | False | False | False
#    |    | False | False | False | False
# ukrainian | ukrainian | True | False | False | False
# saboteurs | saboteurs | True | False | False | False
# trained | trained | True | False | False | False
# fore | fore | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# kyiv | kyiv | True | False | False | False
# school | school | True | False | False | False
# teaches | teaches | True | False | False | False
# forget | forget | True | False | False | False
# russian | russian | True | False | False | False
# langu | langu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# kyiv | kyiv | True | False | False | False
# school | school | True | False | False | False
# teaches | teaches | True | False | False | False
# forget | forget | True | False | False | False
# russian | russian | True | False | False | False
# langu | langu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# kyiv | kyiv | True | False | False | False
# school | school | True | False | False | False
# teaches | teaches | True | False | False | False
# forget | forget | True | False | False | False
# russian | russian | True | False | False | False
# langu | langu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# kyiv | kyiv | True | False | False | False
# school | school | True | False | False | False
# teaches | teaches | True | False | False | False
# forget | forget | True | False | False | False
# russian | russian | True | False | False | False
# langu | langu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# buildings | buildings | True | False | False | False
# american | american | True | False | False | False
# government | government | True | False | False | False
# institutions | institutions | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# petro | petro | True | False | False | False
# poroshenko | poroshenko | True | False | False | False
# aims | aims | True | False | False | False
# violate | violate | True | False | False | False
# agreements | agreements | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russia | russia | True | False | False | False
# alongside | alongside | True | False | False | False
# syrian | syrian | True | False | False | False
# arab | arab | True | False | False | False
# army | army | True | False | False | False
# celebr | celebr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russia | russia | True | False | False | False
# alongside | alongside | True | False | False | False
# syrian | syrian | True | False | False | False
# arab | arab | True | False | False | False
# army | army | True | False | False | False
# celebr | celebr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# germany | germany | True | False | False | False
# warns | warns | True | False | False | False
# sue | sue | True | False | False | False
# refugee | refugee | True | False | False | False
# quotas | quotas | True | False | False | False
# rejecte | rejecte | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# makes | makes | True | False | False | False
# use | use | True | False | False | False
# migrant | migrant | True | False | False | False
# crisis | crisis | True | False | False | False
# create | create | True | False | False | False
# occu | occu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greek | greek | True | False | False | False
# church | church | True | False | False | False
# recognised | recognised | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# orthodo | orthodo | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# makes | makes | True | False | False | False
# use | use | True | False | False | False
# migrant | migrant | True | False | False | False
# crisis | crisis | True | False | False | False
# create | create | True | False | False | False
# occu | occu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# makes | makes | True | False | False | False
# use | use | True | False | False | False
# migrant | migrant | True | False | False | False
# crisis | crisis | True | False | False | False
# create | create | True | False | False | False
# occu | occu | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# data | data | True | False | False | False
# russian | russian | True | False | False | False
# satellite | satellite | True | False | False | False
# revealed | revealed | True | False | False | False
# strong | strong | True | False | False | False
# e | e | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# recently | recently | True | False | False | False
# turkish | turkish | True | False | False | False
# foreign | foreign | True | False | False | False
# minister | minister | True | False | False | False
# declare | declare | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# propaganda | propaganda | True | False | False | False
# work | work | True | False | False | False
# effectively | effectively | True | False | False | False
# united | united | True | False | False | False
# states | states | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# outraged | outraged | True | False | False | False
# mob | mob | True | False | False | False
# geldermalsen | geldermalsen | True | False | False | False
# netherlands | netherlands | True | False | False | False
# int | int | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nationalist | nationalist | True | False | False | False
# organisations | organisations | True | False | False | False
# ukraine | ukraine | True | False | False | False
# supervis | supervis | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nationalist | nationalist | True | False | False | False
# organisations | organisations | True | False | False | False
# ukraine | ukraine | True | False | False | False
# supervis | supervis | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# scandals | scandals | True | False | False | False
# mikhail | mikhail | True | False | False | False
# saakashvili | saakashvili | True | False | False | False
# scandals | scandals | True | False | False | False
# mik | mik | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# putin | putin | True | False | False | False
# fights | fights | True | False | False | False
# jihadis | jihadis | True | False | False | False
#    |    | False | False | False | False
# usbac | usbac | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# football | football | True | False | False | False
# player | player | True | False | False | False
# yevhen | yevhen | True | False | False | False
# konoplia | konoplia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nato | nato | True | False | False | False
# instrument | instrument | True | False | False | False
# foreign | foreign | True | False | False | False
# policy | policy | True | False | False | False
# poses | poses | True | False | False | False
# thr | thr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# kiev | kiev | True | False | False | False
# circumvents | circumvents | True | False | False | False
# minskii | minskii | True | False | False | False
# agre | agre | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# oposition | oposition | True | False | False | False
# block | block | True | False | False | False
# won | won | True | False | False | False
# second | second | True | False | False | False
# place | place | True | False | False | False
#    |    | False | False | False | False
# opos | opos | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# foreigners | foreigners | True | False | False | False
# nt | nt | True | False | False | False
# want | want | True | False | False | False
# adopt | adopt | True | False | False | False
# disabled | disabled | True | False | False | False
# russia | russia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# maidan | maidan | True | False | False | False
# coup | coup | True | False | False | False
# banning | banning | True | False | False | False
# communist | communist | True | False | False | False
# party | party | True | False | False | False
# maid | maid | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# maidan | maidan | True | False | False | False
# coup | coup | True | False | False | False
# banning | banning | True | False | False | False
# communist | communist | True | False | False | False
# party | party | True | False | False | False
# maid | maid | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukraine | ukraine | True | False | False | False
# fascist | fascist | True | False | False | False
# dictatorship | dictatorship | True | False | False | False
# ukraine | ukraine | True | False | False | False
# fasc | fasc | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nations | nations | True | False | False | False
# eu | eu | True | False | False | False
# want | want | True | False | False | False
# speak | speak | True | False | False | False
# nations | nations | True | False | False | False
# eu | eu | True | False | False | False
# want | want | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# usa | usa | True | False | False | False
# provided | provided | True | False | False | False
# terrorists | terrorists | True | False | False | False
# opera | opera | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# propaganda | propaganda | True | False | False | False
# guided | guided | True | False | False | False
# e | e | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# kiev | kiev | True | False | False | False
# circumvents | circumvents | True | False | False | False
# minskii | minskii | True | False | False | False
# agre | agre | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# mikhail | mikhail | True | False | False | False
# khodorkovsky | khodorkovsky | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# citizen | citizen | True | False | False | False
# mi | mi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# mikhail | mikhail | True | False | False | False
# khodorkovsky | khodorkovsky | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# citizen | citizen | True | False | False | False
# mi | mi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# mikhail | mikhail | True | False | False | False
# khodorkovsky | khodorkovsky | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# citizen | citizen | True | False | False | False
# mi | mi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# mikhail | mikhail | True | False | False | False
# khodorkovsky | khodorkovsky | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# citizen | citizen | True | False | False | False
# mi | mi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# mikhail | mikhail | True | False | False | False
# khodorkovsky | khodorkovsky | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# citizen | citizen | True | False | False | False
# mi | mi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# new | new | True | False | False | False
# developments | developments | True | False | False | False
# skripal | skripal | True | False | False | False
# case | case | True | False | False | False
# reveal | reveal | True | False | False | False
# sha | sha | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# americans | americans | True | False | False | False
# support | support | True | False | False | False
# kyiv | kyiv | True | False | False | False
# junta | junta | True | False | False | False
# americans | americans | True | False | False | False
# s | s | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# ukrainian | ukrainian | True | False | False | False
# authorities | authorities | True | False | False | False
# killing | killing | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# national | national | True | False | False | False
# tv | tv | True | False | False | False
# radio | radio | True | False | False | False
# company | company | True | False | False | False
# ukraine | ukraine | True | False | False | False
# direct | direct | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# zakarpattia | zakarpattia | True | False | False | False
# oblast | oblast | True | False | False | False
# region | region | True | False | False | False
# western | western | True | False | False | False
# ukraine | ukraine | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# canteen | canteen | True | False | False | False
# students | students | True | False | False | False
# served | served | True | False | False | False
# militar | militar | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# eu | eu | True | False | False | False
# diplomats | diplomats | True | False | False | False
# officials | officials | True | False | False | False
# outlin | outlin | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russia | russia | True | False | False | False
# covers | covers | True | False | False | False
# syrian | syrian | True | False | False | False
# arab | arab | True | False | False | False
# army | army | True | False | False | False
# prepares | prepares | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# russia | russia | True | False | False | False
# covers | covers | True | False | False | False
# syrian | syrian | True | False | False | False
# arab | arab | True | False | False | False
# army | army | True | False | False | False
# prepares | prepares | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# grim | grim | True | False | False | False
# report | report | True | False | False | False
# circulating | circulating | True | False | False | False
# kremlin | kremlin | True | False | False | False
# prepared | prepared | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# week | week | True | False | False | False
# trend | trend | True | False | False | False
# washington | washington | True | False | False | False
# panics | panics | True | False | False | False
# putin | putin | True | False | False | False
# inter | inter | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# dutch | dutch | True | False | False | False
# invastigation | invastigation | True | False | False | False
# mh | mh | True | False | False | False
# biased | biased | True | False | False | False
# australian | australian | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# dutch | dutch | True | False | False | False
# invastigation | invastigation | True | False | False | False
# mh | mh | True | False | False | False
# biased | biased | True | False | False | False
# australian | australian | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# dutch | dutch | True | False | False | False
# invastigation | invastigation | True | False | False | False
# mh | mh | True | False | False | False
# biased | biased | True | False | False | False
# ...
# climate | climate | True | False | False | False
# movement | movement | True | False | False | False
# distracting | distracting | True | False | False | False
# millions | millions | True | False | False | False
# rea | rea | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# poroshenko | poroshenko | True | False | False | False
# epitome | epitome | True | False | False | False
# war | war | True | False | False | False
# party | party | True | False | False | False
# instigated | instigated | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# hybrid | hybrid | True | False | False | False
# troops | troops | True | False | False | False
# donbas | donbas | True | False | False | False
# kill | kill | True | False | False | False
# famous | famous | True | False | False | False
# opera | opera | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# hybrid | hybrid | True | False | False | False
# troops | troops | True | False | False | False
# donbas | donbas | True | False | False | False
# kill | kill | True | False | False | False
# famous | famous | True | False | False | False
# opera | opera | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ep | ep | True | False | False | False
# resolution | resolution | True | False | False | False
# ideological | ideological | True | False | False | False
# weapon | weapon | True | False | False | False
# russia | russia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greta | greta | True | False | False | False
# thunberg | thunberg | True | False | False | False
# mouthpiece | mouthpiece | True | False | False | False
# lobbyists | lobbyists | True | False | False | False
# green | green | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# turned | turned | True | False | False | False
# ukraine | ukraine | True | False | False | False
# puppet | puppet | True | False | False | False
# ukraine | ukraine | True | False | False | False
# american | american | True | False | False | False
# p | p | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# czechia | czechia | True | False | False | False
# intends | intends | True | False | False | False
# build | build | True | False | False | False
# hotels | hotels | True | False | False | False
# crimea | crimea | True | False | False | False
# dele | dele | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# czechia | czechia | True | False | False | False
# intends | intends | True | False | False | False
# build | build | True | False | False | False
# hotels | hotels | True | False | False | False
# crimea | crimea | True | False | False | False
# dele | dele | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# czechia | czechia | True | False | False | False
# intends | intends | True | False | False | False
# build | build | True | False | False | False
# hotels | hotels | True | False | False | False
# crimea | crimea | True | False | False | False
# dele | dele | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# baltic | baltic | True | False | False | False
# states | states | True | False | False | False
# joined | joined | True | False | False | False
# ussr | ussr | True | False | False | False
# accordance | accordance | True | False | False | False
# int | int | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
#   |   | False | False | False | False
# coup | coup | True | False | False | False
# crimea | crimea | True | False | False | False
# voted | voted | True | False | False | False
# overwhelmingly | overwhelmingly | True | False | False | False
# reuni | reuni | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nato | nato | True | False | False | False
# preparing | preparing | True | False | False | False
# attack | attack | True | False | False | False
# russia | russia | True | False | False | False
# nato | nato | True | False | False | False
# develo | develo | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# journalism | journalism | True | False | False | False
# free | free | True | False | False | False
# russia | russia | True | False | False | False
# political | political | True | False | False | False
# correctn | correctn | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nato | nato | True | False | False | False
# eu | eu | True | False | False | False
# actively | actively | True | False | False | False
# fabricating | fabricating | True | False | False | False
# russophobia | russophobia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# controls | controls | True | False | False | False
# moldova | moldova | True | False | False | False
# moldova | moldova | True | False | False | False
# controls | controls | True | False | False | False
# fact | fact | True | False | False | False
# p | p | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# controls | controls | True | False | False | False
# moldova | moldova | True | False | False | False
# moldova | moldova | True | False | False | False
# controls | controls | True | False | False | False
# fact | fact | True | False | False | False
# p | p | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# crimea | crimea | True | False | False | False
# rejoined | rejoined | True | False | False | False
# russia | russia | True | False | False | False
# referendum | referendum | True | False | False | False
# ukraini | ukraini | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# influx | influx | True | False | False | False
# ukrainians | ukrainians | True | False | False | False
# threatens | threatens | True | False | False | False
# estonia | estonia | True | False | False | False
# massi | massi | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# europe | europe | True | False | False | False
# longer | longer | True | False | False | False
# interested | interested | True | False | False | False
# supporting | supporting | True | False | False | False
# ukrai | ukrai | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greta | greta | True | False | False | False
# thunberg | thunberg | True | False | False | False
# tool | tool | True | False | False | False
# unelected | unelected | True | False | False | False
# global | global | True | False | False | False
# bur | bur | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greta | greta | True | False | False | False
# thunberg | thunberg | True | False | False | False
# prophet | prophet | True | False | False | False
# new | new | True | False | False | False
# totalitarian | totalitarian | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukraine | ukraine | True | False | False | False
# going | going | True | False | False | False
# restore | restore | True | False | False | False
# passenger | passenger | True | False | False | False
# links | links | True | False | False | False
# cr | cr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# belarusian | belarusian | True | False | False | False
# opposition | opposition | True | False | False | False
# tasked | tasked | True | False | False | False
# west | west | True | False | False | False
# disrupt | disrupt | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# dalia | dalia | True | False | False | False
# grybauskaite | grybauskaite | True | False | False | False
# kgb | kgb | True | False | False | False
# agent | agent | True | False | False | False
# initially | initially | True | False | False | False
# g | g | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# provided | provided | True | False | False | False
# economic | economic | True | False | False | False
# subsidies | subsidies | True | False | False | False
# poland | poland | True | False | False | False
# ac | ac | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# swedish | swedish | True | False | False | False
# social | social | True | False | False | False
# services | services | True | False | False | False
# suspect | suspect | True | False | False | False
# greta | greta | True | False | False | False
# th | th | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# greta | greta | True | False | False | False
# thunberg | thunberg | True | False | False | False
# political | political | True | False | False | False
# tool | tool | True | False | False | False
# key | key | True | False | False | False
# target | target | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# nato | nato | True | False | False | False
# fighting | fighting | True | False | False | False
# imaginary | imaginary | True | False | False | False
# russian | russian | True | False | False | False
# threat | threat | True | False | False | False
# u | u | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# estonia | estonia | True | False | False | False
# social | social | True | False | False | False
# moral | moral | True | False | False | False
# occupation | occupation | True | False | False | False
# estonia | estonia | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eu | eu | True | False | False | False
# ignores | ignores | True | False | False | False
# russia | russia | True | False | False | False
# efforts | efforts | True | False | False | False
# reconcile | reconcile | True | False | False | False
# equa | equa | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# eod | eod | True | False | False | False
# centre | centre | True | False | False | False
# moldova | moldova | True | False | False | False
# european | european | True | False | False | False
# command | command | True | False | False | False
# rece | rece | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# occupying | occupying | True | False | False | False
# eu | eu | True | False | False | False
# ; | ; | False | True | False | False
# baltic | baltic | True | False | False | False
# countries | countries | True | False | False | False
# nearly | nearly | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# pentagon | pentagon | True | False | False | False
# plan | plan | True | False | False | False
# destroying | destroying | True | False | False | False
# russian | russian | True | False | False | False
# city | city | True | False | False | False
# ka | ka | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukrainian | ukrainian | True | False | False | False
# soldier | soldier | True | False | False | False
# shot | shot | True | False | False | False
# polish | polish | True | False | False | False
# soldier | soldier | True | False | False | False
# ne | ne | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# ukraine | ukraine | True | False | False | False
# turn | turn | True | False | False | False
# land | land | True | False | False | False
# commodity | commodity | True | False | False | False
# sell | sell | True | False | False | False
# exchang | exchang | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# wants | wants | True | False | False | False
# divide | divide | True | False | False | False
# syria | syria | True | False | False | False
# usa | usa | True | False | False | False
# wants | wants | True | False | False | False
# divide | divide | True | False | False | False
# syr | syr | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# obama | obama | True | False | False | False
# close | close | True | False | False | False
# succeeding | succeeding | True | False | False | False
# hitler | hitler | True | False | False | False
# failed | failed | True | False | False | False
# tea | tea | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# european | european | True | False | False | False
# parliament | parliament | True | False | False | False
# falsifies | falsifies | True | False | False | False
# history | history | True | False | False | False
# mol | mol | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# european | european | True | False | False | False
# parliament | parliament | True | False | False | False
# falsifies | falsifies | True | False | False | False
# history | history | True | False | False | False
# mol | mol | True | False | False | False
# ... | ... | False | True | False | False
# [ | [ | False | True | False | False
# helping | helping | True | False | False | False
# terrorists | terrorists | True | False | False | False
# afghanistan | afghanistan | True | False | False | False
# leading | leading | True | False | False | False
# fs | fs | True | False | False | False
# ... | ... | False | True | False | False

# %%
# POS tagging
nltk.download('averaged_perceptron_tagger')
docs = nlp(text)

tokens = nltk.word_tokenize(text)

classes = nltk.pos_tag(tokens)
print(classes)

#for word in docs:
    #print(word.text,word.pos_)

# %% [markdown]
# ###PALAVRAS E SEUS VALORES SINTATICOS

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()
docs = nlp(text)

for word in docs:
    print(word.text,word.pos_)

# %% [markdown]
# ###ENTIDADES

# %%
from spacy import displacy

doc_ent = nlp(text)

entities = [(i.text, i.label_, i.label) for i in doc_ent.ents]
entities_df = pd.DataFrame(entities, columns=["Entity", "Type", "Type_id"])

# %%
entities_df[entities_df.Type == 'GPE']

# %%
entities_df.to_csv('Entidade.csv', encoding = 'utf-8', index=False)

# %% [markdown]
# ####Entidade identificada destacada por cor e rotulada

# %%
displacy.render(doc_ent, style = "ent",jupyter = True)

# %%
for entidade in doc_ent.ents:
  if entidade.label_ == 'PERSON':
    print(entidade.text)

# %% [markdown]
# #### Análise de dependência de palavras

# %% [markdown]
# PCA
#
# K-MEANS

# %% [markdown]
# #### Vetor de palavras

# %% [markdown]
# Usar p/ K-means

# %%
text_words = df_preprocess['stopwords'].to_string(index=False).replace('\n','').replace(',','').replace('[','').replace(']','').replace('...','')

# %%
text_words
# Out:
# ' normandy summit results eu plays russia benefits attack saudi oil facility regar polish legions pilsudski organized volyn west use eastern europeans cannon fodder resolution european parliament relieves g tentacles george soros entangle politics protests hong kong usfunded growing back antisemitism ukraine rise particular conc threats kaliningrad stands chance ministr western propaganda masters control mass  liberalglobalism totalitarian ideology dom liberalglobalism totalitarian ideology dom sanctions russia unproductive eu sanction support nato ukraine falling number peop wadas decision russia politically motivat foreign aid hinders return syrian refuge western media campaign supports preparati goal crimea takeover save donbaslike civ goal crimea takeover save donbaslike civ molotovribbentrop pact pave way outbreak red army liberated estonia nazi army wa ukrainians paid snitching local corrupt  estonia tool hands eu estonia tool hand red army nt want bomb citizens tallinn terrorists white helmets prepare false f chemical attack khan shaykhun staged whi purpose removing monument marshall konev wants capture kaliningrad exchange crimea european parliament joined forces fascism estonian authorities pay tribute hitlers russophobia driven internal political pro russophobia driven internal political pro russophobia driven internal political pro russophobia driven internal political pro russophobia driven internal political pro russophobia driven internal political pro russophobia driven internal political pro eu army sent suppress new brexits eu a europe creates obstacles cooperation russ lithuania direct beneficiary molotovribben fsb revealed involvement transportation i ussr ally nazi germany ussr ally nazi  ussr ally nazi germany ussr ally nazi  western politicians accuse sputnik rt el drone attack saudi oil facilities false western media distort election results p western media distort election results p moldova refuses support ukrainian plan s moldova refuses support ukrainian plan s russia stop americanisation ukraine way  eu wants create army defend european un mh russia gave evidence joint investigat european parliament carries political hat ep allows destruction monuments fighters ep allows destruction monuments fighters west shown cards russia fall   main bl west shown cards russia fall   main bl cherry sanctions eu fruit exports lose  imperialistic poland feeds animosities uk evidence russian meddling french election brexit greatest victory eu history uks  washington playing religion card societie stronger alliance poland wants dictate r hong kong protests west revenge china w nato preparing command centre germany wa ukraine preparing disruption gas transit   september   ussr began liberating pol eu accept ukraine allowing products mark zelenskyy stands sanctions initiative rig west chose russia main opponent collapse europe transit gas ukraine form subsidy americans interested disrupting gas trans ukrainian gas transmission system environ ukraine willing sign new contract gas t poland blame attacked stalin     septem g countries insignificant fully sovereign poland sympathises willing fight russia  poland sympathises willing fight russia  task european defence agency maintain na isolated ussr alternative sign molotovrib konev monument small clique junior offic removal monument marshall konev violation local gauleiter wants remove statue mars european political elites forced stupidly amnesty international red cross missionar echr makes decisions based antirussian l lovely face liberalism open cannibalism  west organised maidan coup ukraine antir west targeted russia sanctions regimechan shift blame wwii outbreak ribbentropmolot wada decision russia illegal legal point ecj decided limit gazprom access opal p europe saying sanctions useless europeans echr ruling proves european rule law ex admits want involve romania internal aff weaponising human rights human rights qu proof formation pact serbia nato patrona west dest ...

# %%
#análise de tópicos com similaridade

# %%
nlp = spacy.load('en_core_web_sm')
linguagem_num = nlp(text_words)
linguagem_num.vector
# Out:
# array([ 0.18627058, -0.87999386, -2.0100915 ,  0.9734874 ,  0.8522038 ,
#         1.7249123 , -0.3046525 ,  0.48178354,  1.2814395 ,  1.1996671 ,
#         1.6918893 , -0.11180761,  0.78527206, -1.1861224 , -1.5118521 ,
#        -0.8792081 ,  0.06784745,  1.8899151 , -0.48273402, -0.7235786 ,
#         0.56650186, -0.81697243, -0.59198123, -0.1255875 , -0.6179446 ,
#        -0.77374285, -1.2070433 , -0.94965297,  1.3515196 , -1.545287  ,
#         0.4168669 , -1.1277094 ,  0.2099218 , -1.4386    , -0.3874255 ,
#        -1.7970312 ,  1.7968352 , -1.3501809 , -1.5297306 ,  0.2934159 ,
#         2.0609658 ,  1.3113313 ,  0.36332908, -1.3997964 ,  0.0599719 ,
#        -0.09174218, -0.44054532, -0.18021514, -0.5395686 ,  1.1016812 ,
#        -1.0010527 , -0.7253694 ,  0.32070112, -1.053501  , -2.1661205 ,
#         1.2007012 ,  0.38914987,  1.2966263 ,  0.23442398, -0.40944546,
#         0.58311516, -0.18342595,  0.6791531 ,  0.47999957,  1.7097099 ,
#         0.40302595,  0.7127343 , -1.8433818 ,  0.17003809,  1.0533986 ,
#         0.02697986,  0.50929236,  0.1632239 , -0.1870714 , -0.70140636,
#        -1.2602274 ,  0.7900677 , -0.6867624 , -0.2174913 ,  0.55169326,
#         0.49620634, -1.1257539 , -0.84120524, -0.7286985 ,  2.2905445 ,
#         2.1546628 ,  0.4468715 , -1.4464341 , -0.4853015 ,  0.820273  ,
#         0.30160832,  0.30355766,  0.3385021 ,  1.6686877 ,  0.32477129,
#         1.0130072 ], dtype=float32)

# %%
type(linguagem_num.vector)
linguagem_num.vector.shape
# Out:
# (96,)

# %%
linguagem_num[1:3].vector

# %% [markdown]
# ##Biblioteca import

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import spacy
from sklearn.preprocessing import StandardScaler
nlp = spacy.load('en_core_web_sm')

# %%
vocab = nlp(text_words)

words = set(word.text for word in vocab)
vects = np.vstack([word.vector for word in vocab if word.has_vector])
pca = PCA(n_components=2)
vects_transformed = pca.fit_transform(vects)
plt.figure(figsize=(20,15))
plt.scatter(vects_transformed[:,0], vects_transformed[:,1])
for word, coord in zip(words, vects_transformed):
    x,y = coord
    plt.text(x,y,word, size=10)
plt.show()

# %%
docs = nlp(text_words)

tokens = nltk.word_tokenize(text_words)

# %%
tokens_word = list(set(tokens))

# %%
print(len(tokens))
print(len(tokens_word))
# Out:
# 40887
# 7404

# %%
from sklearn.preprocessing import normalize
 
def vectorize(text):
    # Get the SpaCy vector -- turning off other processing to speed things up
    return nlp(text, disable=['parser', 'tagger', 'ner']).vector
 
X = normalize(np.vstack([vectorize(t) for t in text_words]))

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X2 = pca.fit_transform(X)
print("X2 shape is {}".format(X2.shape))
